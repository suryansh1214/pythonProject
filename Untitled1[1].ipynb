# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import pandas as pd
df = pd.read_csv('FMEL_Dataset.csv')
df
# Out:
#           id   season  division  round           localTeam  \
# 0          1  1970-71         1      1  Atletico de Bilbao
# 1          2  1970-71         1      1          Las Palmas
# 2          3  1970-71         1      1         Real Madrid
# 3          4  1970-71         1      1       Celta de Vigo
# 4          5  1970-71         1      1               Elche
# ...      ...      ...       ...    ...                 ...
# 37142  37143  2017-18         2     42          Valladolid
# 37143  37144  2017-18         2     42              Oviedo
# 37144  37145  2017-18         2     42            Alcorcon
# 37145  37146  2017-18         2     42            Numancia
# 37146  37147  2017-18         2     42   Barcelona Atletic
#
#               visitorTeam  localGoals  visitorGoals        date   timestamp
# 0               Barcelona           1             1  12/09/1970    21938400
# 1      Atletico de Madrid           1             1  12/09/1970    21938400
# ...

# %%
#Removing unnessary columns
df.drop(["season","localTeam","visitorTeam","date"], axis=1, inplace=True)

df.head(1)
# Out:
#    id  division  round  localGoals  visitorGoals  timestamp
# 0   1         1      1           1             1   21938400

# %%
df.isnull().sum()
# Out:
# id              0
# division        0
# round           0
# localGoals      0
# visitorGoals    0
# timestamp       0
# dtype: int64

# %%
df.shape
# Out:
# (37147, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37147 entries, 0 to 37146
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            37147 non-null  int64
#  1   division      37147 non-null  int64
#  2   round         37147 non-null  int64
#  3   localGoals    37147 non-null  int64
#  4   visitorGoals  37147 non-null  int64
#  5   timestamp     37147 non-null  int64
# dtypes: int64(6)
# memory usage: 1.7 MB

# %%
df.head(1)
# Out:
#    id  division  round  localGoals  visitorGoals  timestamp
# 0   1         1      1           1             1   21938400

# %%
df.tail(1)
# Out:
#           id  division  round  localGoals  visitorGoals   timestamp
# 37146  37147         2     42           0             2  1527890400

# %%
df.describe()
# Out:
#                  id      division         round    localGoals  visitorGoals  \
# count  37147.000000  37147.000000  37147.000000  37147.000000  37147.000000
# mean   18574.000000      1.537809     19.862896      1.515385      0.936953
# std    10723.559561      0.498575     11.282774      1.262742      1.010263
# min        1.000000      1.000000      1.000000      0.000000      0.000000
# 25%     9287.500000      1.000000     10.000000      1.000000      0.000000
# 50%    18574.000000      2.000000     20.000000      1.000000      1.000000
# 75%    27860.500000      2.000000     29.000000      2.000000      1.000000
# max    37147.000000      2.000000     44.000000     10.000000      8.000000
#
#           timestamp
# count  3.714700e+04
# mean   8.116889e+08
# std    4.322134e+08
# min    2.133360e+07
# 25%    4.453884e+08
# 50%    8.317656e+08
# 75%    1.181426e+09
# max    1.527890e+09

# %%
df.count()
# Out:
# id              37147
# division        37147
# round           37147
# localGoals      37147
# visitorGoals    37147
# timestamp       37147
# dtype: int64

# %%
df.mean()
# Out:
# id              1.857400e+04
# division        1.537809e+00
# round           1.986290e+01
# localGoals      1.515385e+00
# visitorGoals    9.369532e-01
# timestamp       8.116889e+08
# dtype: float64

# %%
df.median()
# Out:
# id                  18574.0
# division                2.0
# round                  20.0
# localGoals              1.0
# visitorGoals            1.0
# timestamp       831765600.0
# dtype: float64

# %%
df.std()
# Out:
# id              1.072356e+04
# division        4.985751e-01
# round           1.128277e+01
# localGoals      1.262742e+00
# visitorGoals    1.010263e+00
# timestamp       4.322134e+08
# dtype: float64

# %%
df.min()
# Out:
# id                     1
# division               1
# round                  1
# localGoals             0
# visitorGoals           0
# timestamp       21333600
# dtype: int64

# %%
df.max()
# Out:
# id                   37147
# division                 2
# round                   44
# localGoals              10
# visitorGoals             8
# timestamp       1527890400
# dtype: int64

# %%
#creating a copy of original df for further use
from sklearn.preprocessing import LabelEncoder

# Fit the LabelEncoder instance to the 'localGoals' column
label_encoder = LabelEncoder()
label_encoder.fit(df['localGoals'])

# Fit the LabelEncoder instance to the 'visitorGoals' column
le_transmission = LabelEncoder()
le_transmission.fit(df['visitorGoals'])

# Now you can inverse transform the columns
namedDf = df.copy()
namedDf['localGoals'] = label_encoder.inverse_transform(label_encoder.transform(df['localGoals']))
namedDf['visitorGoals'] = le_transmission.inverse_transform(le_transmission.transform(df['visitorGoals']))

namedDf.head(1)
# Out:
#    id  division  round  localGoals  visitorGoals  timestamp
# 0   1         1      1           1             1   21938400

# %%
# Histogram
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5,3))
sns.histplot(namedDf['timestamp'], kde = True)
plt.title('Distribution of Football Timestamp')
plt.xlabel('timestamp')
plt.ylabel('Count')
plt.show()

# %%
df
# Out:
#           id  division  round  localGoals  visitorGoals   timestamp
# 0          1         1      1           1             1    21938400
# 1          2         1      1           1             1    21938400
# 2          3         1      1           2             0    21938400
# 3          4         1      1           2             0    22024800
# 4          5         1      1           1             1    22024800
# ...      ...       ...    ...         ...           ...         ...
# 37142  37143         2     42           2             0  1527890400
# 37143  37144         2     42           2             1  1527890400
# 37144  37145         2     42           3             0  1527890400
# 37145  37146         2     42           2             1  1527890400
# 37146  37147         2     42           0             2  1527890400
#
# [37147 rows x 6 columns]

# %%
#Boxplot
plt.figure(figsize=(10,6))
sns.boxplot(x='division' , y='timestamp', data=namedDf, showfliers=False)
plt.title('Price distribution by Credit Score')
plt.xlabel('division')
plt.ylabel('timestamp (in thousands)')
plt.show()

# %%
# Heatmap
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of FMEL_Dataset')
plt.show()

# %%
# Scatter Plot
plt.figure(figsize=(10,6))
sns.scatterplot(x='localGoals', y='timestamp', hue='visitorGoals', data=namedDf)
plt.title('localGoals vs timestamp')
plt.xlabel('round')
plt.ylabel('timestamp')
plt.show()

# %%
df
# Out:
#        Age    Income  Credit Score  Loan Amount  Years at Current Job  \
# 0       49   72799.0         688.0      45713.0                    19
# 2       21   55687.0         600.0      36623.0                     8
# 3       59   26508.0         622.0      26541.0                     2
# 10      42  116212.0         707.0      24771.0                    11
# 16      55   70978.0         706.0      36970.0                    19
# ...    ...       ...           ...          ...                   ...
# 14986   49   29734.0         652.0      44356.0                    13
# 14989   35  108652.0         682.0      21953.0                     9
# 14991   43  110352.0         662.0      36790.0                    13
# 14994   40   43655.0         614.0      34565.0                    11
# 14997   29   46250.0         642.0      44369.0                    19
#
#        Debt-to-Income Ratio  Assets Value  Number of Dependents  \
# ...

# %%
x = df.iloc[:,:-1] #Independent Variable / Features
y = df.iloc[:,-1] #Dependent Variable / Target value

# Train and Test Data Split

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25, random_state = 100)

# %%
x
# Out:
#        Age    Income  Credit Score  Loan Amount  Years at Current Job  \
# 0       49   72799.0         688.0      45713.0                    19
# 2       21   55687.0         600.0      36623.0                     8
# 3       59   26508.0         622.0      26541.0                     2
# 10      42  116212.0         707.0      24771.0                    11
# 16      55   70978.0         706.0      36970.0                    19
# ...    ...       ...           ...          ...                   ...
# 14986   49   29734.0         652.0      44356.0                    13
# 14989   35  108652.0         682.0      21953.0                     9
# 14991   43  110352.0         662.0      36790.0                    13
# 14994   40   43655.0         614.0      34565.0                    11
# 14997   29   46250.0         642.0      44369.0                    19
#
#        Debt-to-Income Ratio  Assets Value  Number of Dependents  \
# ...

# %%
y
# Out:
# 0        2
# 2        2
# 3        2
# 10       2
# 16       0
#         ..
# 14986    0
# 14989    1
# 14991    1
# 14994    1
# 14997    1
# Name: Marital Status Change, Length: 5716, dtype: int64

# %%
x_train
# Out:
#        Age    Income  Credit Score  Loan Amount  Years at Current Job  \
# 44      21   73952.0         631.0      49525.0                     3
# 7871    19  112917.0         645.0      15687.0                     1
# 2316    29   59038.0         600.0      12745.0                    14
# 1534    40   78097.0         663.0      26963.0                     6
# 4638    64   85573.0         667.0      14241.0                    16
# ...    ...       ...           ...          ...                   ...
# 4891    23   35648.0         705.0       5496.0                     1
# 936     29  116921.0         747.0      36076.0                     7
# 233     65   27826.0         736.0      43125.0                    18
# 10254   21   63715.0         686.0      27814.0                     2
# 14789   42   54314.0         629.0       6188.0                     5
#
#        Debt-to-Income Ratio  Assets Value  Number of Dependents  \
# ...

# %%
x_test
# Out:
#        Age   Income  Credit Score  Loan Amount  Years at Current Job  \
# 1735    57  85552.0         678.0      48738.0                     3
# 9482    69  81713.0         798.0       5678.0                     4
# 11749   29  85696.0         614.0      49095.0                     9
# 8517    68  39693.0         790.0      30117.0                     3
# 10322   52  24782.0         654.0      46997.0                    12
# ...    ...      ...           ...          ...                   ...
# 8744    64  34323.0         647.0      41776.0                    15
# 6567    55  52863.0         704.0      32398.0                     4
# 13950   50  55732.0         664.0      18926.0                     7
# 7651    61  74987.0         713.0      47276.0                    12
# 7442    22  42333.0         790.0      39459.0                     4
#
#        Debt-to-Income Ratio  Assets Value  Number of Dependents  \
# 1735               0.486409       96099.0                   0.0
# ...

# %%
y_test
# Out:
# 1735     2
# 9482     1
# 11749    1
# 8517     0
# 10322    1
#         ..
# 8744     2
# 6567     1
# 13950    0
# 7651     0
# 7442     0
# Name: Marital Status Change, Length: 1429, dtype: int64

# %%
y_train
# Out:
# 44       2
# 7871     0
# 2316     0
# 1534     2
# 4638     1
#         ..
# 4891     1
# 936      2
# 233      1
# 10254    2
# 14789    0
# Name: Marital Status Change, Length: 4287, dtype: int64

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

# Scaling of the Data
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
# Model Selection and Building
from sklearn.linear_model import LinearRegression
regression = LinearRegression(n_jobs= -1)

# model Training
regression.fit(x_train,y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
# Multi Linear Regression Model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

regression = LinearRegression(n_jobs= -1)
regression.fit(x_train,y_train)
y_pred = regression.predict(x_test)

score1 = r2_score(y_test,y_pred)
print("R2 Score: ", score1)
# Out:
# R2 Score:  -0.003891656198913074

# %%
# Decision Tree Regression Model
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()
dt.fit(x_train,y_train)
y_pred2 = dt.predict(x_test)

score2 = r2_score(y_test, y_pred2)
print("R2 Score: ", score2)
# Out:
# R2 Score:  -1.0319980862068712

# %%
# Random Forest Regression Model
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(x_train,y_train)
y_pred3 = rf.predict(x_test)

score3 = r2_score(y_test, y_pred3)
print("R2 Score: ", score3)
# Out:
# R2 Score:  -0.031157281700541883

# %%
# Comparison of Different Models Prediction​

a = pd.DataFrame({"Algorithm":['Linear Regressor','Decision_Tree','Random-Forest'],
                  "Accuracy": [score1,score2,score3],
                  "prediction-1":[y_pred[1],y_pred2[1],y_pred3[1]]},)
a
# Out:
#           Algorithm  Accuracy  prediction-1
# 0  Linear Regressor -0.003892      0.987093
# 1     Decision_Tree -1.031998      1.000000
# 2     Random-Forest -0.031157      0.940000
